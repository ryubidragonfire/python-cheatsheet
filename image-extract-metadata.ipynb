# %% [markdown]
# ## Extract Meta Data about Image
#
# ref: Data Source: https://www.google.co.uk/search?q=carrizo+image+data&rlz=1C1CHBF_en-GBGB804GB804&oq=carrizo+image+data&aqs=chrome..69i57j69i60.3198j0j4&sourceid=chrome&ie=UTF-8#

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

image = Image.open('./data/13cam6-952.JPG')
plt.imshow(image)

# %%
import exifread

fname = './data/13cam6-952.JPG'

with open(fname, 'rb') as f:
    tags = exifread.process_file(f); tags
    if 'EXIF DateTimeOriginal' in tags.keys():
        tags['EXIF DateTimeOriginal'].values
# Out:
# {'EXIF ApertureValue': (0x9202) Ratio=14/5 @ 4824,
#  'EXIF ColorSpace': (0xA001) Short=sRGB @ 2564,
#  'EXIF ComponentsConfiguration': (0x9101) Undefined=YCbCr @ 2432,
#  'EXIF CompressedBitsPerPixel': (0x9102) Ratio=240335/314928 @ 4808,
#  'EXIF DateTimeDigitized': (0x9004) ASCII=2015:04:13 14:05:53 @ 4788,
#  'EXIF DateTimeOriginal': (0x9003) ASCII=2015:04:13 14:05:53 @ 4768,
#  'EXIF ExifImageLength': (0xA003) Long=1944 @ 2588,
#  'EXIF ExifImageWidth': (0xA002) Long=2592 @ 2576,
#  'EXIF ExifVersion': (0x9000) Undefined=0210 @ 2396,
#  'EXIF ExposureBiasValue': (0x9204) Short=[0, 0, 18, 0] @ 4832,
#  'EXIF ExposureIndex': (0xA215) Ratio=1 @ 5342,
#  'EXIF ExposureProgram': (0x8822) Short=Aperture Priority @ 2372,
#  'EXIF ExposureTime': (0x829A) Ratio=0 @ 4752,
#  'EXIF FNumber': (0x829D) Ratio=14/5 @ 4760,
#  'EXIF FileSource': (0xA300) Undefined=Digital Camera @ 2648,
#  'EXIF Flash': (0x9209) Short=Flash did not fire @ 2528,
# ...
