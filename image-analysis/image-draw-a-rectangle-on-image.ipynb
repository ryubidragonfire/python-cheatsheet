# %%
## Histogram for image
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

image = Image.open('./data/toothless.jpg')
plt.imshow(image)

# %%
from PIL import Image, ImageFont, ImageDraw, ImageEnhance

draw = ImageDraw.Draw(image)
draw.rectangle(((0, 0), (100, 100)), fill=None, outline='red')
draw.text((20, 70), "Fish!")


plt.imshow(image)
image.save('./data/toothless-rect.jpg', "JPEG")

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread('./data/toothless.jpg')
img = cv2.rectangle(img, (200,5), (125,50), (0,255,0), 4)

# put text
bottomLeftCornerOfText = (125, 80)
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 0.5
fontColor = (0, 255, 0)
lineType = cv2.LINE_4

img = cv2.putText(img,'This One!', 
                  bottomLeftCornerOfText, 
                  font, 
                  fontScale,
                  fontColor,
                  lineType)

#### -> Kernel died ...
#cv2.imshow('new image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.imshow(img)
plt.show()
