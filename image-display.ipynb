# %% [markdown]
# ## Display Images
#
# https://matplotlib.org/users/image_tutorial.html

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('./data/toothless.jpg')
plt.imshow(image)

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('./data/toothless.jpg')

plt.subplot(1,2,1)
plt.imshow(image)

plt.subplot(1,2,2)
plt.imshow(image)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cvutils
# %matplotlib inline

images = cvutils.imlist("/datadisk/dtd/images/polka-dotted/")

n=6

for i in range(1,n):
    plt.subplot(1,n,i)
    plt.imshow(Image.open(images[i]))

    plt.subplot(1,n,i)
    plt.imshow(Image.open(images[i]))

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "none"
import cvutils
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
    
# %matplotlib inline

images_list = cvutils.imlist("/dlvmdata/kaggle/dogs-vs-cats/small/test/cats/")
number_images_per_row = 5
number_of_images_to_display = 20

j = np.ceil(len(images_list)/number_images_per_row)

plt.figure(figsize=(20, 400))
for i in range(len(images_list[0:number_of_images_to_display])):
    img = Image.open(images_list[i])
    plt.subplot(j, number_images_per_row, i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
from IPython.display import Image

Image(filename='./data/toothless.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('./data/toothless.jpg')

plt.subplot(1,2,1)
imgplot = plt.imshow(img)

plt.subplot(1,2,2)
imgplot = plt.imshow(img)

plt.show()

# %% [markdown]
# ## Display randomly sampled images from a folder

# %%
import os
import random
from IPython.display import display, Image

def display_random_samples(folder, sample_size):
    image_files = os.listdir(folder)
    image_sample = random.sample(image_files, sample_size)
    for image in image_sample:
        image_file = os.path.join(folder, image)
        i = Image(filename=image_file)
        display(i)

# %% [markdown]
# ## Display an array

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

a = np.zeros([1,3])
a
plt.imshow(a, cmap='gray')
# Out:
# array([[ 0.,  0.,  0.]])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

b = np.ndarray([1,3])
b
b.shape
plt.imshow(b, cmap='gray')
# Out:
# array([[ 0.,  0.,  1.]])
# (1, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

b = np.ndarray([1,3])
b
b.shape
plt.matshow(b, cmap='viridis')
# Out:
# array([[-1.,  0.,  1.]])
# (1, 3)

# %% [markdown]
# ## CV2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

img = cv2.imread('./data/toothless.jpg')
###
# OpenCV uses BGR as its default colour order for images, matplotlib uses RGB. 
# When you display an image loaded with OpenCv in matplotlib the channels will be back to front.
# The easiest way of fixing this is to use OpenCV to explicitly convert it back to RGB
###

_ = plt.subplot(1,4,1)
_ = plt.imshow(img)

img2 = img[:,:,::-1]; img2.shape
_ = plt.subplot(1,4,1)
_ = plt.imshow(img2)

img2 = img[:,::-1,:]; img2.shape
_ = plt.subplot(1,4,2)
_ = plt.imshow(img2)

img2 = img[::-1,:,:]; img2.shape
_ = plt.subplot(1,4,3)
_ = plt.imshow(img2)
# Out:
# (224, 225, 3)
# (224, 225, 3)
# (224, 225, 3)
