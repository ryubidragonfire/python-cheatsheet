# %% [markdown]
# # Visualising Data
# - Distribution
#     - Histogram
#     - Boxplot
# - Correlation
#     - Scatter plot
#
# - Trend
#     - Parallel coordinates

# %%
# Working with multiple figure windows and subplots
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s1 = np.sin(2*np.pi*t)
s2 = np.sin(4*np.pi*t)

plt.subplot(1,2,1)
plt.plot(t, s1)

plt.subplot(1,2,2)
plt.plot(t, 2*s1)

plt.show()
plt.gcf().clear()

# %%
import windrose

# %%
from matplotlib import pyplot as plt
import windrose
import matplotlib.cm as cm
import numpy as np

#ws = [1, 2, 3, 4, 5]
#wd = [360, (360/2), (360/3), (360/4), (360/5)]; print(wd)

ws = []
wd = []

fig = plt.figure(figsize=(30,20))
ax = fig.add_subplot(221, projection="windrose")

ax.contourf(wd, ws, bins=np.arange(0, 10, 1), cmap=cm.hot)

labels = ['Innovation', 'Azure Consumption', 'Technology Gaps', 'Industry Sector', 'XXX']
angle_grid = range(0,360,72)
ax.set_thetagrids(angle_grid, labels)
ax.set_yticklabels([])

#ax.legend(bbox_to_anchor=(1.02, 0))
plt.show()

# %%
help(ax.set_yticklabels)
# Out:
# Help on method set_yticklabels in module matplotlib.axes._base:
#
# set_yticklabels(labels, fontdict=None, minor=False, **kwargs) method of matplotlib.axes._subplots.WindroseAxesSubplot instance
#     Set the y tick labels with list of strings *labels*
#
#     Return a list of :class:`~matplotlib.text.Text` instances.
#
#     *kwargs* set :class:`~matplotlib.text.Text` properties for the labels.
#     Valid properties are
#       agg_filter: unknown
#       alpha: float (0.0 transparent through 1.0 opaque)
#       animated: [True | False]
#       axes: an :class:`~matplotlib.axes.Axes` instance
#       backgroundcolor: any matplotlib color
#       bbox: FancyBboxPatch prop dict
#       clip_box: a :class:`matplotlib.transforms.Bbox` instance
#       clip_on: [True | False]
#       clip_path: [ (:class:`~matplotlib.path.Path`, :class:`~matplotlib.transforms.Transform`) | :class:`~matplotlib.patches.Patch` | None ]
#       color: any matplotlib color
# ...

# %%
wd
# Out:
# [360, 180.0, 120.0, 90.0, 72.0]

# %%
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np
# %matplotlib inline

# Create wind speed and direction variables

ws = np.random.random(500) * 6
wd = np.random.random(500) * 360

# %%
ax = WindroseAxes.from_ax()
ax.bar(wd, ws, normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
ax.set_yticklabels(['a', 'b', 'c'])
ax.set_thetagrids([100,200], ['100', '200'])
# Out:
# (<a list of 4 Line2D ticklines objects>,
#  <a list of 2 Text major ticklabel objects>)

# %%
ws = np.random.random(5) * 6; print(ws)
wd = np.random.random(5) * 360; print(wd)

ax = WindroseAxes.from_ax()
ax.bar(wd, ws, normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
#ax.set_yticklabels(['a', 'b', 'c'])
labels = ['Innovation', 'Azure Consumption', 'Technology Gaps', 'Industry Sector', 'XXX']
angle_grid = range(0,360,72)
ax.set_thetagrids(angle_grid, labels)
# Out:
# [ 5.78182744  2.85403986  3.38311143  3.20155346  5.82029566]
# [ 349.18901238  324.47947806  251.75578967  219.39078646  358.89898949]
# (<a list of 10 Line2D ticklines objects>,
#  <a list of 5 Text major ticklabel objects>)

# %%
360/5
# Out:
# 72.0

# %%
angle_r=np.pi*((450-angle)%360)/180
angle_grid = range(0,360,45)
label = ['E','NE','N','NO','O','SO','S','SE']

ax = plt.subplot(1,1,1, polar='True')
ax.set_thetagrids(angle_grid,label)

ax.plot(angle_r,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b38f8ed4e4f5> in <module>()
# ----> 1 angle_r=np.pi*((450-angle)%360)/180
#       2 angle_grid = range(0,360,45)
#       3 label = ['E','NE','N','NO','O','SO','S','SE']
#       4
#       5 ax = plt.subplot(1,1,1, polar='True')
#
# NameError: name 'angle' is not defined
