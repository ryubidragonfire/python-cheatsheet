# %%
## Histogram for image
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

image = Image.open('./data/toothless.jpg')
plt.imshow(image)

# %% [markdown]
# ## Display image meta data

# %% [markdown]
# ### `exiv2`

# %%
# !exiv2 ./data/toothless.jpg
# Out:
# File name       : ./data/toothless.jpg
# File size       : 7860 Bytes
# MIME type       : image/jpeg
# Image size      : 225 x 224
# ./data/toothless.jpg: No Exif data found in the file

# %% [markdown]
# ### `file`

# %%
# !file ./data/toothless.jpg
# Out:
# ./data/toothless.jpg: JPEG image data, JFIF standard 1.01, aspect ratio, density 1x1, segment length 16, baseline, precision 8, 225x224, frames 3

# %% [markdown]
# ### `identify`

# %%
# !identify ./data/toothless.jpg
# Out:
# ./data/toothless.jpg JPEG 225x224 225x224+0+0 8-bit sRGB 7.86KB 0.000u 0:00.000
