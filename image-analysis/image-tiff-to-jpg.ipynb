# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Tiff to Jpg: RGB example

# %%
InteractiveShell.ast_node_interactivity = "none"
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np

fname = './data/0000_rgb.tiff'
img = cv2.imread(fname)

if img is None:
    print('Failed to load image file: ', fname)
    sys.exit(1)
    
else:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.axis('off')
    plt.imshow(img)
    print(img.shape)
# Out:
# (679, 1024, 3)

# %%
cv2.imwrite('./data/0000_rgb.jpg', img)

plt.axis('off')
plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')
plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')
plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
print(img.shape)
# Out:
# (679, 1024, 3)

# %%
fname = './data/0000_rgb.jpg'
img = cv2.imread(fname)

if img is None:
    print('Failed to load image file: ', fname)
    sys.exit(1)
    
else:
    plt.axis('off')
    plt.imshow(img)
    print(img.shape)
# Out:
# (679, 1024, 3)

# %% [markdown]
# ### Tiff to Jpg: NIR example

# %%
InteractiveShell.ast_node_interactivity = "none"
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np

fname = './data/0000_nir.tiff'
img = cv2.imread(fname)

if img is None:
    print('Failed to load image file: ', fname)
    sys.exit(1)
    
else:
    plt.axis('off')
    plt.imshow(img)
    print(img.shape)
# Out:
# (679, 1024, 3)

# %%
cv2.imwrite('./data/0000_nir.jpg', img)

plt.axis('off')
plt.subplot(1,3,1)
plt.imshow(img[:,:,0], cmap='gray')
plt.subplot(1,3,2)
plt.imshow(img[:,:,1], cmap='gray')
plt.subplot(1,3,3)
plt.imshow(img[:,:,2], cmap='gray')
print(img.shape)
# Out:
# (679, 1024, 3)
